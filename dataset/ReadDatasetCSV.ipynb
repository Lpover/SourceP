# %%
import pandas as pd
import numpy as np

# %%
filename = "PonziDataset_6498.csv"
data = pd.read_csv(filename, low_memory=False, encoding='ISO-8859-1')
data
# Out:
#                                              sourcecode   idx  \
# 0     contract TerraNullius {\r\r\n  struct Claim { ...     1
# 1     contract MyScheme {\r\r\n \r\r\n    uint treeB...     2
# 2     contract Faucet {\r\r\n    uint256 sendAmount;...     3
# 3     contract Roulette {\r\r\n    \r\r\n    // Glob...     4
# 4     contract HonestDice {\r\r\n\t\r\r\n\tevent Bet...     5
# ...                                                 ...   ...
# 6493  /**\r\r\n\r\r\n *Submitted for verification at...  6494
# 6494  /**\r\r\n\r\r\n *Submitted for verification at...  6495
# 6495  /**\r\r\n\r\r\n *Submitted for verification at...  6496
# 6496  /**\r\r\n\r\r\n *Submitted for verification at...  6497
# 6497  /**\r\r\n\r\r\n *Submitted for verification at...  6498
#
#                                          address
# 0     0x6e38a457c722c6011b2dfa06d49240e797844d66
# 1     0x109c4f2ccc82c4d77bde15f306707320294aea3f
# 2     0x793ae8c1b1a160bfc07bfb0d04f85eab1a71f4f2
# ...
